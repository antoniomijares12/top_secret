# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings

# %%
busquedas3 = pd.read_excel("RAW/DATOS INPUT.xlsx", sheet_name='Búsquedas a tres meses', header = 3)
busquedas3
# Out:
#    Etiquetas de fila        DE        DK        ES       FI        FR  \
# 0            2019-01    390095    252447    248836    90786    271023
# 1            2019-02    372062    262999    249147    90023    201188
# 2            2019-03    405078    287247    290156   101802    263866
# 3            2019-04    376287    243601    299507    66568    252702
# 4            2019-05    414791    214424    317756    56018    302971
# ..               ...       ...       ...       ...      ...       ...
# 56           2023-09    652748    266164   1102675   139804    398132
# 57           2023-10    539068    315287   1265311   111359    402352
# 58           2023-11    449919    454807   1083760   103474    318000
# 59           2023-12    443113    511444   1057806   102997    303186
# 60     Total general  28937035  12489432  37422393  4292449  17714658
#
#            GB       IE       NO        SE        IT       PL       NL  \
# ...

# %%
busquedas3 = busquedas3.rename(columns={'Etiquetas de fila': 'Fecha'}) # Cambiamos el nombre a fecha
busquedas3
# Out:
#             Fecha        DE        DK        ES       FI        FR         GB  \
# 0         2019-01    390095    252447    248836    90786    271023    1581704
# 1         2019-02    372062    262999    249147    90023    201188    1737175
# 2         2019-03    405078    287247    290156   101802    263866    2022997
# 3         2019-04    376287    243601    299507    66568    252702    2226281
# 4         2019-05    414791    214424    317756    56018    302971    2886671
# ..            ...       ...       ...       ...      ...       ...        ...
# 56        2023-09    652748    266164   1102675   139804    398132    1311398
# 57        2023-10    539068    315287   1265311   111359    402352    1157720
# 58        2023-11    449919    454807   1083760   103474    318000    1291356
# 59        2023-12    443113    511444   1057806   102997    303186    1343901
# 60  Total general  28937035  12489432  37422393  4292449  17714658  100377385
#
# ...

# %%
busquedas3.duplicated().sum()
# Out:
# 0

# %%
busquedas3.isnull().sum()
# Out:
# Fecha            0
# DE               0
# DK               0
# ES               0
# FI               0
# FR               0
# GB               0
# IE               0
# NO               0
# SE               0
# IT               0
# PL               0
# NL               0
# BE               0
# PT               0
# AT               0
# Total general    0
# dtype: int64

# %%
busquedas3.to_excel("Limpio/busquedas3_clean.xlsx", index=False)

# %%
busquedas3
# Out:
#             Fecha        DE        DK        ES       FI        FR         GB  \
# 0         2019-01    390095    252447    248836    90786    271023    1581704
# 1         2019-02    372062    262999    249147    90023    201188    1737175
# 2         2019-03    405078    287247    290156   101802    263866    2022997
# 3         2019-04    376287    243601    299507    66568    252702    2226281
# 4         2019-05    414791    214424    317756    56018    302971    2886671
# ..            ...       ...       ...       ...      ...       ...        ...
# 56        2023-09    652748    266164   1102675   139804    398132    1311398
# 57        2023-10    539068    315287   1265311   111359    402352    1157720
# 58        2023-11    449919    454807   1083760   103474    318000    1291356
# 59        2023-12    443113    511444   1057806   102997    303186    1343901
# 60  Total general  28937035  12489432  37422393  4292449  17714658  100377385
#
# ...
