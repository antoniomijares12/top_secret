# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings

# %%
busquedas12 = pd.read_excel("RAW/DATOS INPUT.xlsx", sheet_name='Búsquedas viajar 12 meses', header = 3)
busquedas12
# Out:
#    Etiquetas de fila        DE        DK        ES       FI        FR  \
# 0            2019-01    816231    469044    359708   155539    448329
# 1            2019-02    727090    465141    356589   138173    317218
# 2            2019-03    773615    478102    399551   149869    396565
# 3            2019-04    684838    333806    391773   101922    351011
# 4            2019-05    725771    292337    381650    84382    366209
# ..               ...       ...       ...       ...      ...       ...
# 56           2023-09    652748    266164   1102675   139804    398132
# 57           2023-10    493620    284944   1170206    99662    373110
# 58           2023-11    321133    314893    801272    67632    234836
# 59           2023-12    145490    144127    352564    27345    106752
# 60     Total general  40980827  16356992  42303329  5609423  21997419
#
#            GB       IE       NO        SE        IT       PL       NL  \
# ...

# %%
busquedas12 = busquedas12.rename(columns={'Etiquetas de fila': 'Fecha'}) # Cambiamos el nombre a fecha

# %%
busquedas12.duplicated().sum()
# Out:
# 0

# %%
busquedas12.isnull().sum()
# Out:
# Fecha            0
# DE               0
# DK               0
# ES               0
# FI               0
# FR               0
# GB               0
# IE               0
# NO               0
# SE               0
# IT               0
# PL               0
# NL               0
# BE               0
# PT               0
# AT               0
# Total general    0
# dtype: int64

# %%
busquedas12.describe().round()
# Out:
#                DE          DK          ES         FI          FR           GB  \
# count        61.0        61.0        61.0       61.0        61.0         61.0
# mean    1343634.0    536295.0   1386994.0   183916.0    721227.0    4738753.0
# std     5166081.0   2064989.0   5350925.0   708488.0   2777496.0   18241949.0
# min      145490.0     27663.0     57992.0    13859.0     33644.0     439866.0
# 25%      422529.0    161350.0    282070.0    33879.0    186230.0    1109960.0
# 50%      712193.0    281733.0    491574.0    99662.0    395652.0    2430888.0
# 75%      901101.0    410755.0   1131294.0   138173.0    522086.0    3448650.0
# max    40980827.0  16356992.0  42303329.0  5609423.0  21997419.0  144531960.0
#
#               IE         NO          SE          IT         PL         NL  \
# count       61.0       61.0        61.0        61.0       61.0       61.0
# mean    271619.0   296822.0    875232.0    934883.0   277966.0   300676.0
# ...

# %%
busquedas12['DE'].sum() - busquedas12['DE'].max()  # Compruebo que el total por país este bien calculado
# Out:
# 40980827

# %%
busquedas12.iloc[0, 1: 16].sum() # Compruebo que el total por fecha esta bien calculado
# Out:
# 8011194

# %%
pd.to_datetime(busquedas12['Fecha'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 pd.to_datetime(busquedas12['Fecha'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...
