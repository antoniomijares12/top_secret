# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings

# %%
busquedas6 = pd.read_excel("RAW/DATOS INPUT.xlsx", sheet_name='Búsquedas a 6 meses', header = 3)
busquedas6
# Out:
#    Etiquetas de fila        DE        DK        ES       FI        FR  \
# 0            2019-01    598902    411990    323062   131985    388208
# 1            2019-02    547062    411450    331989   118191    295381
# 2            2019-03    589666    437989    380792   129399    379500
# 3            2019-04    536834    320153    378821    93252    343448
# 4            2019-05    573769    278175    369421    76734    357641
# ..               ...       ...       ...       ...      ...       ...
# 56           2023-09    726662    303338   1200285   159075    435833
# 57           2023-10    646514    395136   1417030   137703    480222
# 58           2023-11    596924    613434   1265724   135600    417025
# 59           2023-12    580315    677899   1257105   130351    408637
# 60     Total general  36289274  16026154  42591021  5384529  21458382
#
#            GB       IE       NO        SE        IT       PL       NL  \
# ...

# %%
busquedas6 = busquedas6.rename(columns={'Etiquetas de fila': 'Fecha'})# Cambiamos el nombre a fecha
busquedas6
# Out:
#             Fecha        DE        DK        ES       FI        FR         GB  \
# 0         2019-01    598902    411990    323062   131985    388208    2981446
# 1         2019-02    547062    411450    331989   118191    295381    2670078
# 2         2019-03    589666    437989    380792   129399    379500    2896715
# 3         2019-04    536834    320153    378821    93252    343448    3111495
# 4         2019-05    573769    278175    369421    76734    357641    3672768
# ..            ...       ...       ...       ...      ...       ...        ...
# 56        2023-09    726662    303338   1200285   159075    435833    1452536
# 57        2023-10    646514    395136   1417030   137703    480222    1353003
# 58        2023-11    596924    613434   1265724   135600    417025    1710880
# 59        2023-12    580315    677899   1257105   130351    408637    1826940
# 60  Total general  36289274  16026154  42591021  5384529  21458382  129252189
#
# ...

# %%
busquedas6.duplicated().sum()
# Out:
# 0

# %%
busquedas6.isnull().sum()
# Out:
# Fecha            0
# DE               0
# DK               0
# ES               0
# FI               0
# FR               0
# GB               0
# IE               0
# NO               0
# SE               0
# IT               0
# PL               0
# NL               0
# BE               0
# PT               0
# AT               0
# Total general    0
# dtype: int64
